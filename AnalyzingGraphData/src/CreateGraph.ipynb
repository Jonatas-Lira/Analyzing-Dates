# %%
import matplotlib.pyplot as plt
from collections import Counter

# %%
idades = [57, 61, 57, 57, 58, 57, 61, 54, 68, 51, 49, 64, 50, 48, 65, 52, 56, 46, 54, 49, 51, 47, 55, 55, 54, 42, 51, 56, 55, 51, 54, 51, 60, 61, 43, 55, 56, 61, 52, 69, 64, 46, 54, 47, 70, 78]

counts = Counter(idades).most_common()

Comuns, frequente = counts[0]

x = list(range(1, len(idades) + 1))

# %%
plt.scatter(idades, x, color='blue')
print(f"A idade mais comum entre os presidentes é {frequente}")
plt.show()
# Out:
# A idade mais comum entre os presidentes é 5
